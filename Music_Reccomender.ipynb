# %%
'''Work in progress'''
'''Code will not run properly as I have not moved the Music_Data.csv file over yet'''
import pandas as pd
from sklearn.tree import DecisionTreeClassifier


Music_Data = pd.read_csv('Music_Data.csv')
X = Music_Data.drop(columns=['Genre'])
y = Music_Data['Genre']

model = DecisionTreeClassifier()
model.fit(X,y)
'''First column = Age, second column = gender (0=Female, 1=Male), third column = mood (0=angry 1=happy)'''
predictions = model.predict( [ [24,1,0],[21,1,1] ] )
predictions
'''algorithm was given 2 inputs, so the 2 outputs would be "Metal" and "RandB" '''
